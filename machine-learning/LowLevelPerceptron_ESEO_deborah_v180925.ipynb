# %% [markdown]
# # **Implémentation d'un perceptron bas niveau**
# # L'objectif est de modéliser un classifieur binaire basé sur un cas d'étude pour autoriser ou non un train d'entrer dans un canton.

# %% [markdown]
# # **Partie I**
#
#
#  > # Codage de la fonction d'activation

# %%
import numpy as np
import random
import math

# %%
#@title 1 - les données d'apprentissage

# Création des données d'observations dans une variable de type array
c1_c2 = np.array([[0, 0, 1], [0, 1, 1], [1, 0, 0], [1, 1, 0]])

# Création des données attendues dans une variable de type array
A = np.array([[1], [1], [0], [0]])

# %%
#@title 2 - les poids

#### Les poids sont dans un premier temps générés de façon aléatoire dans un intervalle.
#### Nous choisirons l'intervalle [-1;1] car la fonction random donne des valeurs comprises dans cet intervalle.

# Initialisation des poids dans l'intervalle [-1;1]
random.seed(1)
borneMin = -1
borneMax = 1

# Calculez les valeurs de poids requis pour initialiser le perceptron
# Nous modéliserons ces valeurs par une fonction affine y = ax+b
# comme étant l'image de notre valeur aléatoire
# a représente l'amplitude de notre intervalle
a =  borneMax - borneMin

# b représente la borne minimale de notre intervalle
b = borneMin

# Initialisation du biais qui aura pour valeur 1
# et de son poids qui aura pour valeur nulle
biais = 1
wb =0

x  = random.random()
y = a * x + b

#initialisation des poids du perceptron
w11 = y
w21 = y

# %%
#@title 3 - les hyperparamètres

#### Les hyperparamètres décrivent des éléments importants
#### dans la configuration du perceptron en vue de son apprentissage

# Taux d'apprentissage
txApprentissage = 0.1

# Nombre d'epochs
epochs = 300

# %%
#@title 4 - les fonctions utiles

#### Pour mettre en oeuvre le perceptron, nous aurons besoin
#### d'un certain nombre de fonctions comme celles d'activation,
#### de calcul pour la mise à jour des poids, d'erreurs, etc.

# Ecrire la fonction de la somme pondérée qui servira à préactiver le neurone
def somme_ponderee(X1,W11,X2,W21,B,WB):
   return X1*W11+X2*W21+B*WB

# %%
def fonction_activation_sigmoide(valeur_somme_ponderee):
   return 1 / (1 + math.exp(-valeur_somme_ponderee))

# %%
# la fonction d'activation relu: une fonction non linéaire qui renvoie la valeur d'entrée si elle est positive, et zéro sinon
def fonction_activation_relu(valeur_somme_ponderee):
   if valeur_somme_ponderee >= 0:
    return valeur_somme_ponderee
   else:
    return 0

# %%
#la fonction de calcul d'erreur linéaire
def erreur_lineaire(valeur_attendue, valeur_predite):
   return valeur_predite - valeur_attendue

# %%
# Ecrire la fonction de calcul du gradient
def calcul_gradient(valeur_entree,prediction,erreur):
   return erreur * valeur_entree

# %%
# Ecrire la fonction d'optimisation pour ajuster les valeurs des poids
def calcul_valeur_ajustement(valeur_gradient,taux_apprentissage):
   return - taux_apprentissage * valeur_gradient

# %%
# Ecrire la fonction de mise à jour des poids
def calcul_nouveau_poids (valeur_poids, valeur_ajustement):
   valeur_poids+=valeur_ajustement
   return valeur_poids

# %%
# Ecrire la fonction de calcul d'erreur entre la prédiction et le résultat attendu
def calcul_MSE(predictions_realisees, predictions_attendues):
   i=0;
   somme_quadratique = 0
   for i in range(len(predictions_realisees)):
       somme_quadratique += (predictions_realisees[i] - predictions_attendues[i])**2
   moyenne_quadratique = somme_quadratique / len(predictions_realisees)
   return moyenne_quadratique

# %%
# Préparation d'une liste pour stocker les données de la fonction de perte
# quadratique MSE tout au long de l'apprentissage
Graphique_MSE = []

# Entraînement sur plusieurs époques
for epoch in range(0, epochs):
    print("EPOCH (" + str(epoch) + "/" + str(epochs) + ")")
    predictions_realisees_durant_epoch = []
    predictions_attendues = []
    numObservation = 0
    for observation in c1_c2:

        # Chargement de la couche d'entrée
        x1 = observation[0]
        x2 = observation[1]

        # Valeur de prédiction attendue
        ya = observation[2]

        # Étape 1 : Calcul de la somme pondérée
        Sp = somme_ponderee(x1, w11, x2, w21, biais, wb)

        # Étape 2 : Application de la fonction d'activation (sigmoïde, puis Relu)
        yp = fonction_activation_sigmoide(Sp)

        # Étape 3 : Calcul de l'erreur
        err = erreur_lineaire(ya, yp)

        # Mise à jour du poids 1
        # Calcul du gradient de la valeur d'ajustement et du nouveau poids
        g1 = calcul_gradient(x1, yp, err)
        va1 = calcul_valeur_ajustement(g1, txApprentissage)
        w11 = calcul_nouveau_poids(w11, va1)

        # Mise à jour du poids 2
        g2 = calcul_gradient(x2, yp, err)
        va2 = calcul_valeur_ajustement(g2, txApprentissage)
        w21 = calcul_nouveau_poids(w21, va2)

        # Mise à jour du poids du biais
        gb = calcul_gradient(biais, yp, err)
        vab = calcul_valeur_ajustement(gb, txApprentissage)
        wb = calcul_nouveau_poids(wb, vab)

        print("     EPOCH (" + str(epoch) + "/" + str(epochs) + ") - Observation: " + str(numObservation + 1) + "/" + str(len(c1_c2)))

        # Stockage de la prédiction réalisée:
        predictions_realisees_durant_epoch.append(yp)

        # Stockage de la valeur attendue:
        predictions_attendues.append(ya)

        # Passage à l'observation suivante
        numObservation = numObservation + 1

    # Calcul de la fonction d'erreur quadratique MSE
    MSE = calcul_MSE(predictions_realisees_durant_epoch, predictions_attendues)
    Graphique_MSE.append(MSE)
    print("MSE : " + str(MSE))
# Out:
# EPOCH (0/300)
#      EPOCH (0/300) - Observation: 1/4
#      EPOCH (0/300) - Observation: 2/4
#      EPOCH (0/300) - Observation: 3/4
#      EPOCH (0/300) - Observation: 4/4
# MSE : 0.21830589533594558
# EPOCH (1/300)
#      EPOCH (1/300) - Observation: 1/4
#      EPOCH (1/300) - Observation: 2/4
#      EPOCH (1/300) - Observation: 3/4
#      EPOCH (1/300) - Observation: 4/4
# MSE : 0.20712270717381573
# EPOCH (2/300)
#      EPOCH (2/300) - Observation: 1/4
#      EPOCH (2/300) - Observation: 2/4
#      EPOCH (2/300) - Observation: 3/4
#      EPOCH (2/300) - Observation: 4/4
# MSE : 0.19670937003385602
# EPOCH (3/300)
#      EPOCH (3/300) - Observation: 1/4
#      EPOCH (3/300) - Observation: 2/4
#      EPOCH (3/300) - Observation: 3/4
#      EPOCH (3/300) - Observation: 4/4
# MSE : 0.18702175624548278
# EPOCH (4/300)
#      EPOCH (4/300) - Observation: 1/4
#      EPOCH (4/300) - Observation: 2/4
#      EPOCH (4/300) - Observation: 3/4
#      EPOCH (4/300) - Observation: 4/4
# MSE : 0.17800849273586153
# EPOCH (5/300)
#      EPOCH (5/300) - Observation: 1/4
#      EPOCH (5/300) - Observation: 2/4
#      EPOCH (5/300) - Observation: 3/4
#      EPOCH (5/300) - Observation: 4/4
# MSE : 0.16961586110080054
# EPOCH (6/300)
#      EPOCH (6/300) - Observation: 1/4
#      EPOCH (6/300) - Observation: 2/4
#      EPOCH (6/300) - Observation: 3/4
#      EPOCH (6/300) - Observation: 4/4
# MSE : 0.16179110373035965
# EPOCH (7/300)
#      EPOCH (7/300) - Observation: 1/4
#      EPOCH (7/300) - Observation: 2/4
#      EPOCH (7/300) - Observation: 3/4
#      EPOCH (7/300) - Observation: 4/4
# MSE : 0.15448442245243557
# EPOCH (8/300)
#      EPOCH (8/300) - Observation: 1/4
#      EPOCH (8/300) - Observation: 2/4
#      EPOCH (8/300) - Observation: 3/4
#      EPOCH (8/300) - Observation: 4/4
# MSE : 0.14765000713844145
# EPOCH (9/300)
#      EPOCH (9/300) - Observation: 1/4
#      EPOCH (9/300) - Observation: 2/4
#      EPOCH (9/300) - Observation: 3/4
#      EPOCH (9/300) - Observation: 4/4
# MSE : 0.1412464037403693
# EPOCH (10/300)
#      EPOCH (10/300) - Observation: 1/4
#      EPOCH (10/300) - Observation: 2/4
#      EPOCH (10/300) - Observation: 3/4
#      EPOCH (10/300) - Observation: 4/4
# MSE : 0.13523646963827968
# EPOCH (11/300)
#      EPOCH (11/300) - Observation: 1/4
#      EPOCH (11/300) - Observation: 2/4
#      EPOCH (11/300) - Observation: 3/4
#      EPOCH (11/300) - Observation: 4/4
# MSE : 0.12958709710959615
# EPOCH (12/300)
#      EPOCH (12/300) - Observation: 1/4
#      EPOCH (12/300) - Observation: 2/4
#      EPOCH (12/300) - Observation: 3/4
#      EPOCH (12/300) - Observation: 4/4
# MSE : 0.12426882713115914
# EPOCH (13/300)
#      EPOCH (13/300) - Observation: 1/4
#      EPOCH (13/300) - Observation: 2/4
#      EPOCH (13/300) - Observation: 3/4
#      EPOCH (13/300) - Observation: 4/4
# MSE : 0.1192554303322468
# EPOCH (14/300)
#      EPOCH (14/300) - Observation: 1/4
#      EPOCH (14/300) - Observation: 2/4
#      EPOCH (14/300) - Observation: 3/4
#      EPOCH (14/300) - Observation: 4/4
# MSE : 0.11452349954964398
# EPOCH (15/300)
#      EPOCH (15/300) - Observation: 1/4
#      EPOCH (15/300) - Observation: 2/4
#      EPOCH (15/300) - Observation: 3/4
#      EPOCH (15/300) - Observation: 4/4
# MSE : 0.11005207684591647
# EPOCH (16/300)
#      EPOCH (16/300) - Observation: 1/4
#      EPOCH (16/300) - Observation: 2/4
#      EPOCH (16/300) - Observation: 3/4
#      EPOCH (16/300) - Observation: 4/4
# MSE : 0.1058223243213939
# EPOCH (17/300)
#      EPOCH (17/300) - Observation: 1/4
#      EPOCH (17/300) - Observation: 2/4
#      EPOCH (17/300) - Observation: 3/4
#      EPOCH (17/300) - Observation: 4/4
# MSE : 0.10181724013349386
# EPOCH (18/300)
#      EPOCH (18/300) - Observation: 1/4
#      EPOCH (18/300) - Observation: 2/4
#      EPOCH (18/300) - Observation: 3/4
#      EPOCH (18/300) - Observation: 4/4
# MSE : 0.09802141691122353
# EPOCH (19/300)
#      EPOCH (19/300) - Observation: 1/4
#      EPOCH (19/300) - Observation: 2/4
#      EPOCH (19/300) - Observation: 3/4
#      EPOCH (19/300) - Observation: 4/4
# MSE : 0.0944208378262913
# EPOCH (20/300)
#      EPOCH (20/300) - Observation: 1/4
#      EPOCH (20/300) - Observation: 2/4
#      EPOCH (20/300) - Observation: 3/4
#      EPOCH (20/300) - Observation: 4/4
# MSE : 0.09100270500652673
# EPOCH (21/300)
#      EPOCH (21/300) - Observation: 1/4
#      EPOCH (21/300) - Observation: 2/4
#      EPOCH (21/300) - Observation: 3/4
#      EPOCH (21/300) - Observation: 4/4
# MSE : 0.08775529513689335
# EPOCH (22/300)
#      EPOCH (22/300) - Observation: 1/4
#      EPOCH (22/300) - Observation: 2/4
#      EPOCH (22/300) - Observation: 3/4
#      EPOCH (22/300) - Observation: 4/4
# MSE : 0.08466783760747537
# EPOCH (23/300)
#      EPOCH (23/300) - Observation: 1/4
#      EPOCH (23/300) - Observation: 2/4
#      EPOCH (23/300) - Observation: 3/4
#      EPOCH (23/300) - Observation: 4/4
# MSE : 0.08173041121254686
# EPOCH (24/300)
#      EPOCH (24/300) - Observation: 1/4
#      EPOCH (24/300) - Observation: 2/4
#      EPOCH (24/300) - Observation: 3/4
#      EPOCH (24/300) - Observation: 4/4
# MSE : 0.07893385605686012
# EPOCH (25/300)
#      EPOCH (25/300) - Observation: 1/4
#      EPOCH (25/300) - Observation: 2/4
#      EPOCH (25/300) - Observation: 3/4
#      EPOCH (25/300) - Observation: 4/4
# MSE : 0.07626969792313283
# EPOCH (26/300)
#      EPOCH (26/300) - Observation: 1/4
#      EPOCH (26/300) - Observation: 2/4
#      EPOCH (26/300) - Observation: 3/4
#      EPOCH (26/300) - Observation: 4/4
# MSE : 0.07373008287322358
# EPOCH (27/300)
#      EPOCH (27/300) - Observation: 1/4
#      EPOCH (27/300) - Observation: 2/4
#      EPOCH (27/300) - Observation: 3/4
#      EPOCH (27/300) - Observation: 4/4
# MSE : 0.07130772028968514
# EPOCH (28/300)
#      EPOCH (28/300) - Observation: 1/4
#      EPOCH (28/300) - Observation: 2/4
#      EPOCH (28/300) - Observation: 3/4
#      EPOCH (28/300) - Observation: 4/4
# MSE : 0.06899583291958729
# EPOCH (29/300)
#      EPOCH (29/300) - Observation: 1/4
#      EPOCH (29/300) - Observation: 2/4
#      EPOCH (29/300) - Observation: 3/4
#      EPOCH (29/300) - Observation: 4/4
# MSE : 0.06678811276849159
# EPOCH (30/300)
#      EPOCH (30/300) - Observation: 1/4
#      EPOCH (30/300) - Observation: 2/4
#      EPOCH (30/300) - Observation: 3/4
#      EPOCH (30/300) - Observation: 4/4
# MSE : 0.06467868192026932
# EPOCH (31/300)
#      EPOCH (31/300) - Observation: 1/4
#      EPOCH (31/300) - Observation: 2/4
#      EPOCH (31/300) - Observation: 3/4
#      EPOCH (31/300) - Observation: 4/4
# MSE : 0.06266205753866803
# EPOCH (32/300)
#      EPOCH (32/300) - Observation: 1/4
#      EPOCH (32/300) - Observation: 2/4
#      EPOCH (32/300) - Observation: 3/4
#      EPOCH (32/300) - Observation: 4/4
# MSE : 0.060733120448543315
# EPOCH (33/300)
#      EPOCH (33/300) - Observation: 1/4
#      EPOCH (33/300) - Observation: 2/4
#      EPOCH (33/300) - Observation: 3/4
#      EPOCH (33/300) - Observation: 4/4
# MSE : 0.05888708680641465
# EPOCH (34/300)
#      EPOCH (34/300) - Observation: 1/4
#      EPOCH (34/300) - Observation: 2/4
#      EPOCH (34/300) - Observation: 3/4
#      EPOCH (34/300) - Observation: 4/4
# MSE : 0.05711948245798603
# EPOCH (35/300)
#      EPOCH (35/300) - Observation: 1/4
#      EPOCH (35/300) - Observation: 2/4
#      EPOCH (35/300) - Observation: 3/4
#      EPOCH (35/300) - Observation: 4/4
# MSE : 0.05542611964971612
# EPOCH (36/300)
#      EPOCH (36/300) - Observation: 1/4
#      EPOCH (36/300) - Observation: 2/4
#      EPOCH (36/300) - Observation: 3/4
#      EPOCH (36/300) - Observation: 4/4
# MSE : 0.05380307581655211
# EPOCH (37/300)
#      EPOCH (37/300) - Observation: 1/4
#      EPOCH (37/300) - Observation: 2/4
#      EPOCH (37/300) - Observation: 3/4
#      EPOCH (37/300) - Observation: 4/4
# MSE : 0.05224667421178923
# EPOCH (38/300)
#      EPOCH (38/300) - Observation: 1/4
#      EPOCH (38/300) - Observation: 2/4
#      EPOCH (38/300) - Observation: 3/4
#      EPOCH (38/300) - Observation: 4/4
# MSE : 0.050753466180182435
# EPOCH (39/300)
#      EPOCH (39/300) - Observation: 1/4
#      EPOCH (39/300) - Observation: 2/4
#      EPOCH (39/300) - Observation: 3/4
#      EPOCH (39/300) - Observation: 4/4
# MSE : 0.049320214903854305
# EPOCH (40/300)
#      EPOCH (40/300) - Observation: 1/4
#      EPOCH (40/300) - Observation: 2/4
#      EPOCH (40/300) - Observation: 3/4
#      EPOCH (40/300) - Observation: 4/4
# MSE : 0.0479438804737024
# EPOCH (41/300)
#      EPOCH (41/300) - Observation: 1/4
#      EPOCH (41/300) - Observation: 2/4
#      EPOCH (41/300) - Observation: 3/4
#      EPOCH (41/300) - Observation: 4/4
# MSE : 0.046621606158046176
# EPOCH (42/300)
#      EPOCH (42/300) - Observation: 1/4
#      EPOCH (42/300) - Observation: 2/4
#      EPOCH (42/300) - Observation: 3/4
#      EPOCH (42/300) - Observation: 4/4
# MSE : 0.04535070575605262
# EPOCH (43/300)
#      EPOCH (43/300) - Observation: 1/4
#      EPOCH (43/300) - Observation: 2/4
#      EPOCH (43/300) - Observation: 3/4
#      EPOCH (43/300) - Observation: 4/4
# MSE : 0.04412865193670921
# EPOCH (44/300)
#      EPOCH (44/300) - Observation: 1/4
#      EPOCH (44/300) - Observation: 2/4
#      EPOCH (44/300) - Observation: 3/4
#      EPOCH (44/300) - Observation: 4/4
# MSE : 0.04295306547529337
# EPOCH (45/300)
#      EPOCH (45/300) - Observation: 1/4
#      EPOCH (45/300) - Observation: 2/4
#      EPOCH (45/300) - Observation: 3/4
#      EPOCH (45/300) - Observation: 4/4
# MSE : 0.04182170530882169
# EPOCH (46/300)
#      EPOCH (46/300) - Observation: 1/4
#      EPOCH (46/300) - Observation: 2/4
#      EPOCH (46/300) - Observation: 3/4
#      EPOCH (46/300) - Observation: 4/4
# MSE : 0.04073245934015768
# EPOCH (47/300)
#      EPOCH (47/300) - Observation: 1/4
#      EPOCH (47/300) - Observation: 2/4
#      EPOCH (47/300) - Observation: 3/4
#      EPOCH (47/300) - Observation: 4/4
# MSE : 0.0396833359275584
# EPOCH (48/300)
#      EPOCH (48/300) - Observation: 1/4
#      EPOCH (48/300) - Observation: 2/4
#      EPOCH (48/300) - Observation: 3/4
#      EPOCH (48/300) - Observation: 4/4
# MSE : 0.038672456002638037
# EPOCH (49/300)
#      EPOCH (49/300) - Observation: 1/4
#      EPOCH (49/300) - Observation: 2/4
#      EPOCH (49/300) - Observation: 3/4
#      EPOCH (49/300) - Observation: 4/4
# MSE : 0.0376980457651685
# EPOCH (50/300)
#      EPOCH (50/300) - Observation: 1/4
#      EPOCH (50/300) - Observation: 2/4
#      EPOCH (50/300) - Observation: 3/4
#      EPOCH (50/300) - Observation: 4/4
# MSE : 0.036758429907944916
# EPOCH (51/300)
#      EPOCH (51/300) - Observation: 1/4
#      EPOCH (51/300) - Observation: 2/4
#      EPOCH (51/300) - Observation: 3/4
#      EPOCH (51/300) - Observation: 4/4
# MSE : 0.035852025329213395
# EPOCH (52/300)
#      EPOCH (52/300) - Observation: 1/4
#      EPOCH (52/300) - Observation: 2/4
#      EPOCH (52/300) - Observation: 3/4
#      EPOCH (52/300) - Observation: 4/4
# MSE : 0.034977335293964296
# EPOCH (53/300)
#      EPOCH (53/300) - Observation: 1/4
#      EPOCH (53/300) - Observation: 2/4
#      EPOCH (53/300) - Observation: 3/4
#      EPOCH (53/300) - Observation: 4/4
# MSE : 0.034132944008804
# EPOCH (54/300)
#      EPOCH (54/300) - Observation: 1/4
#      EPOCH (54/300) - Observation: 2/4
#      EPOCH (54/300) - Observation: 3/4
#      EPOCH (54/300) - Observation: 4/4
# MSE : 0.033317511578179776
# EPOCH (55/300)
#      EPOCH (55/300) - Observation: 1/4
#      EPOCH (55/300) - Observation: 2/4
#      EPOCH (55/300) - Observation: 3/4
#      EPOCH (55/300) - Observation: 4/4
# MSE : 0.032529769312492955
# EPOCH (56/300)
#      EPOCH (56/300) - Observation: 1/4
#      EPOCH (56/300) - Observation: 2/4
#      EPOCH (56/300) - Observation: 3/4
#      EPOCH (56/300) - Observation: 4/4
# MSE : 0.03176851536112776
# EPOCH (57/300)
#      EPOCH (57/300) - Observation: 1/4
#      EPOCH (57/300) - Observation: 2/4
#      EPOCH (57/300) - Observation: 3/4
#      EPOCH (57/300) - Observation: 4/4
# MSE : 0.031032610645681614
# EPOCH (58/300)
#      EPOCH (58/300) - Observation: 1/4
#      EPOCH (58/300) - Observation: 2/4
#      EPOCH (58/300) - Observation: 3/4
#      EPOCH (58/300) - Observation: 4/4
# MSE : 0.03032097507072971
# EPOCH (59/300)
#      EPOCH (59/300) - Observation: 1/4
#      EPOCH (59/300) - Observation: 2/4
#      EPOCH (59/300) - Observation: 3/4
#      EPOCH (59/300) - Observation: 4/4
# MSE : 0.02963258399131893
# EPOCH (60/300)
#      EPOCH (60/300) - Observation: 1/4
#      EPOCH (60/300) - Observation: 2/4
#      EPOCH (60/300) - Observation: 3/4
#      EPOCH (60/300) - Observation: 4/4
# MSE : 0.028966464918078492
# EPOCH (61/300)
#      EPOCH (61/300) - Observation: 1/4
#      EPOCH (61/300) - Observation: 2/4
#      EPOCH (61/300) - Observation: 3/4
#      EPOCH (61/300) - Observation: 4/4
# MSE : 0.0283216944423801
# EPOCH (62/300)
#      EPOCH (62/300) - Observation: 1/4
#      EPOCH (62/300) - Observation: 2/4
#      EPOCH (62/300) - Observation: 3/4
#      EPOCH (62/300) - Observation: 4/4
# MSE : 0.02769739536538652
# EPOCH (63/300)
#      EPOCH (63/300) - Observation: 1/4
#      EPOCH (63/300) - Observation: 2/4
#      EPOCH (63/300) - Observation: 3/4
#      EPOCH (63/300) - Observation: 4/4
# MSE : 0.027092734016115748
# EPOCH (64/300)
#      EPOCH (64/300) - Observation: 1/4
#      EPOCH (64/300) - Observation: 2/4
#      EPOCH (64/300) - Observation: 3/4
#      EPOCH (64/300) - Observation: 4/4
# MSE : 0.026506917744821504
# EPOCH (65/300)
#      EPOCH (65/300) - Observation: 1/4
#      EPOCH (65/300) - Observation: 2/4
#      EPOCH (65/300) - Observation: 3/4
#      EPOCH (65/300) - Observation: 4/4
# MSE : 0.025939192579067943
# EPOCH (66/300)
#      EPOCH (66/300) - Observation: 1/4
#      EPOCH (66/300) - Observation: 2/4
#      EPOCH (66/300) - Observation: 3/4
#      EPOCH (66/300) - Observation: 4/4
# MSE : 0.025388841030860438
# EPOCH (67/300)
#      EPOCH (67/300) - Observation: 1/4
#      EPOCH (67/300) - Observation: 2/4
#      EPOCH (67/300) - Observation: 3/4
#      EPOCH (67/300) - Observation: 4/4
# MSE : 0.024855180044096585
# EPOCH (68/300)
#      EPOCH (68/300) - Observation: 1/4
#      EPOCH (68/300) - Observation: 2/4
#      EPOCH (68/300) - Observation: 3/4
#      EPOCH (68/300) - Observation: 4/4
# MSE : 0.02433755907242907
# EPOCH (69/300)
#      EPOCH (69/300) - Observation: 1/4
#      EPOCH (69/300) - Observation: 2/4
#      EPOCH (69/300) - Observation: 3/4
#      EPOCH (69/300) - Observation: 4/4
# MSE : 0.023835358278390596
# EPOCH (70/300)
#      EPOCH (70/300) - Observation: 1/4
#      EPOCH (70/300) - Observation: 2/4
#      EPOCH (70/300) - Observation: 3/4
#      EPOCH (70/300) - Observation: 4/4
# MSE : 0.023347986845327656
# EPOCH (71/300)
#      EPOCH (71/300) - Observation: 1/4
#      EPOCH (71/300) - Observation: 2/4
#      EPOCH (71/300) - Observation: 3/4
#      EPOCH (71/300) - Observation: 4/4
# MSE : 0.022874881394329843
# EPOCH (72/300)
#      EPOCH (72/300) - Observation: 1/4
#      EPOCH (72/300) - Observation: 2/4
#      EPOCH (72/300) - Observation: 3/4
#      EPOCH (72/300) - Observation: 4/4
# MSE : 0.022415504498929203
# EPOCH (73/300)
#      EPOCH (73/300) - Observation: 1/4
#      EPOCH (73/300) - Observation: 2/4
#      EPOCH (73/300) - Observation: 3/4
#      EPOCH (73/300) - Observation: 4/4
# MSE : 0.02196934329088399
# EPOCH (74/300)
#      EPOCH (74/300) - Observation: 1/4
#      EPOCH (74/300) - Observation: 2/4
#      EPOCH (74/300) - Observation: 3/4
#      EPOCH (74/300) - Observation: 4/4
# MSE : 0.021535908150859324
# EPOCH (75/300)
#      EPOCH (75/300) - Observation: 1/4
#      EPOCH (75/300) - Observation: 2/4
#      EPOCH (75/300) - Observation: 3/4
#      EPOCH (75/300) - Observation: 4/4
# MSE : 0.021114731478273717
# EPOCH (76/300)
#      EPOCH (76/300) - Observation: 1/4
#      EPOCH (76/300) - Observation: 2/4
#      EPOCH (76/300) - Observation: 3/4
#      EPOCH (76/300) - Observation: 4/4
# MSE : 0.02070536653500214
# EPOCH (77/300)
#      EPOCH (77/300) - Observation: 1/4
#      EPOCH (77/300) - Observation: 2/4
#      EPOCH (77/300) - Observation: 3/4
#      EPOCH (77/300) - Observation: 4/4
# MSE : 0.020307386358014264
# EPOCH (78/300)
#      EPOCH (78/300) - Observation: 1/4
#      EPOCH (78/300) - Observation: 2/4
#      EPOCH (78/300) - Observation: 3/4
#      EPOCH (78/300) - Observation: 4/4
# MSE : 0.019920382736383656
# EPOCH (79/300)
#      EPOCH (79/300) - Observation: 1/4
#      EPOCH (79/300) - Observation: 2/4
#      EPOCH (79/300) - Observation: 3/4
#      EPOCH (79/300) - Observation: 4/4
# MSE : 0.01954396524843369
# EPOCH (80/300)
#      EPOCH (80/300) - Observation: 1/4
#      EPOCH (80/300) - Observation: 2/4
#      EPOCH (80/300) - Observation: 3/4
#      EPOCH (80/300) - Observation: 4/4
# MSE : 0.019177760355089918
# EPOCH (81/300)
#      EPOCH (81/300) - Observation: 1/4
#      EPOCH (81/300) - Observation: 2/4
#      EPOCH (81/300) - Observation: 3/4
#      EPOCH (81/300) - Observation: 4/4
# MSE : 0.018821410545788876
# EPOCH (82/300)
#      EPOCH (82/300) - Observation: 1/4
#      EPOCH (82/300) - Observation: 2/4
#      EPOCH (82/300) - Observation: 3/4
#      EPOCH (82/300) - Observation: 4/4
# MSE : 0.01847457353355276
# EPOCH (83/300)
#      EPOCH (83/300) - Observation: 1/4
#      EPOCH (83/300) - Observation: 2/4
#      EPOCH (83/300) - Observation: 3/4
#      EPOCH (83/300) - Observation: 4/4
# MSE : 0.018136921496078245
# EPOCH (84/300)
#      EPOCH (84/300) - Observation: 1/4
#      EPOCH (84/300) - Observation: 2/4
#      EPOCH (84/300) - Observation: 3/4
#      EPOCH (84/300) - Observation: 4/4
# MSE : 0.01780814035990886
# EPOCH (85/300)
#      EPOCH (85/300) - Observation: 1/4
#      EPOCH (85/300) - Observation: 2/4
#      EPOCH (85/300) - Observation: 3/4
#      EPOCH (85/300) - Observation: 4/4
# MSE : 0.01748792912496482
# EPOCH (86/300)
#      EPOCH (86/300) - Observation: 1/4
#      EPOCH (86/300) - Observation: 2/4
#      EPOCH (86/300) - Observation: 3/4
#      EPOCH (86/300) - Observation: 4/4
# MSE : 0.01717599922689291
# EPOCH (87/300)
#      EPOCH (87/300) - Observation: 1/4
#      EPOCH (87/300) - Observation: 2/4
#      EPOCH (87/300) - Observation: 3/4
#      EPOCH (87/300) - Observation: 4/4
# MSE : 0.01687207393487385
# EPOCH (88/300)
#      EPOCH (88/300) - Observation: 1/4
#      EPOCH (88/300) - Observation: 2/4
#      EPOCH (88/300) - Observation: 3/4
#      EPOCH (88/300) - Observation: 4/4
# MSE : 0.01657588778268665
# EPOCH (89/300)
#      EPOCH (89/300) - Observation: 1/4
#      EPOCH (89/300) - Observation: 2/4
#      EPOCH (89/300) - Observation: 3/4
#      EPOCH (89/300) - Observation: 4/4
# MSE : 0.016287186030979166
# EPOCH (90/300)
#      EPOCH (90/300) - Observation: 1/4
#      EPOCH (90/300) - Observation: 2/4
#      EPOCH (90/300) - Observation: 3/4
#      EPOCH (90/300) - Observation: 4/4
# MSE : 0.016005724158832488
# EPOCH (91/300)
#      EPOCH (91/300) - Observation: 1/4
#      EPOCH (91/300) - Observation: 2/4
#      EPOCH (91/300) - Observation: 3/4
#      EPOCH (91/300) - Observation: 4/4
# MSE : 0.015731267382836023
# EPOCH (92/300)
#      EPOCH (92/300) - Observation: 1/4
#      EPOCH (92/300) - Observation: 2/4
#      EPOCH (92/300) - Observation: 3/4
#      EPOCH (92/300) - Observation: 4/4
# MSE : 0.015463590202009367
# EPOCH (93/300)
#      EPOCH (93/300) - Observation: 1/4
#      EPOCH (93/300) - Observation: 2/4
#      EPOCH (93/300) - Observation: 3/4
#      EPOCH (93/300) - Observation: 4/4
# MSE : 0.015202475967016823
# EPOCH (94/300)
#      EPOCH (94/300) - Observation: 1/4
#      EPOCH (94/300) - Observation: 2/4
#      EPOCH (94/300) - Observation: 3/4
#      EPOCH (94/300) - Observation: 4/4
# MSE : 0.014947716472224645
# EPOCH (95/300)
#      EPOCH (95/300) - Observation: 1/4
#      EPOCH (95/300) - Observation: 2/4
#      EPOCH (95/300) - Observation: 3/4
#      EPOCH (95/300) - Observation: 4/4
# MSE : 0.01469911156924467
# EPOCH (96/300)
#      EPOCH (96/300) - Observation: 1/4
#      EPOCH (96/300) - Observation: 2/4
#      EPOCH (96/300) - Observation: 3/4
#      EPOCH (96/300) - Observation: 4/4
# MSE : 0.014456468800697878
# EPOCH (97/300)
#      EPOCH (97/300) - Observation: 1/4
#      EPOCH (97/300) - Observation: 2/4
#      EPOCH (97/300) - Observation: 3/4
#      EPOCH (97/300) - Observation: 4/4
# MSE : 0.014219603053013131
# EPOCH (98/300)
#      EPOCH (98/300) - Observation: 1/4
#      EPOCH (98/300) - Observation: 2/4
#      EPOCH (98/300) - Observation: 3/4
#      EPOCH (98/300) - Observation: 4/4
# MSE : 0.013988336227152441
# EPOCH (99/300)
#      EPOCH (99/300) - Observation: 1/4
#      EPOCH (99/300) - Observation: 2/4
#      EPOCH (99/300) - Observation: 3/4
#      EPOCH (99/300) - Observation: 4/4
# MSE : 0.013762496926226104
# EPOCH (100/300)
#      EPOCH (100/300) - Observation: 1/4
#      EPOCH (100/300) - Observation: 2/4
#      EPOCH (100/300) - Observation: 3/4
#      EPOCH (100/300) - Observation: 4/4
# MSE : 0.013541920159026218
# EPOCH (101/300)
#      EPOCH (101/300) - Observation: 1/4
#      EPOCH (101/300) - Observation: 2/4
#      EPOCH (101/300) - Observation: 3/4
#      EPOCH (101/300) - Observation: 4/4
# MSE : 0.013326447058569401
# EPOCH (102/300)
#      EPOCH (102/300) - Observation: 1/4
#      EPOCH (102/300) - Observation: 2/4
#      EPOCH (102/300) - Observation: 3/4
#      EPOCH (102/300) - Observation: 4/4
# MSE : 0.013115924614796316
# EPOCH (103/300)
#      EPOCH (103/300) - Observation: 1/4
#      EPOCH (103/300) - Observation: 2/4
#      EPOCH (103/300) - Observation: 3/4
#      EPOCH (103/300) - Observation: 4/4
# MSE : 0.01291020542062947
# EPOCH (104/300)
#      EPOCH (104/300) - Observation: 1/4
#      EPOCH (104/300) - Observation: 2/4
#      EPOCH (104/300) - Observation: 3/4
#      EPOCH (104/300) - Observation: 4/4
# MSE : 0.012709147430639833
# EPOCH (105/300)
#      EPOCH (105/300) - Observation: 1/4
#      EPOCH (105/300) - Observation: 2/4
#      EPOCH (105/300) - Observation: 3/4
#      EPOCH (105/300) - Observation: 4/4
# MSE : 0.012512613731620187
# EPOCH (106/300)
#      EPOCH (106/300) - Observation: 1/4
#      EPOCH (106/300) - Observation: 2/4
#      EPOCH (106/300) - Observation: 3/4
#      EPOCH (106/300) - Observation: 4/4
# MSE : 0.012320472324405165
# EPOCH (107/300)
#      EPOCH (107/300) - Observation: 1/4
#      EPOCH (107/300) - Observation: 2/4
#      EPOCH (107/300) - Observation: 3/4
#      EPOCH (107/300) - Observation: 4/4
# MSE : 0.01213259591631928
# EPOCH (108/300)
#      EPOCH (108/300) - Observation: 1/4
#      EPOCH (108/300) - Observation: 2/4
#      EPOCH (108/300) - Observation: 3/4
#      EPOCH (108/300) - Observation: 4/4
# MSE : 0.011948861723671404
# EPOCH (109/300)
#      EPOCH (109/300) - Observation: 1/4
#      EPOCH (109/300) - Observation: 2/4
#      EPOCH (109/300) - Observation: 3/4
#      EPOCH (109/300) - Observation: 4/4
# MSE : 0.011769151283749422
# EPOCH (110/300)
#      EPOCH (110/300) - Observation: 1/4
#      EPOCH (110/300) - Observation: 2/4
#      EPOCH (110/300) - Observation: 3/4
#      EPOCH (110/300) - Observation: 4/4
# MSE : 0.011593350275801637
# EPOCH (111/300)
#      EPOCH (111/300) - Observation: 1/4
#      EPOCH (111/300) - Observation: 2/4
#      EPOCH (111/300) - Observation: 3/4
#      EPOCH (111/300) - Observation: 4/4
# MSE : 0.011421348350522038
# EPOCH (112/300)
#      EPOCH (112/300) - Observation: 1/4
#      EPOCH (112/300) - Observation: 2/4
#      EPOCH (112/300) - Observation: 3/4
#      EPOCH (112/300) - Observation: 4/4
# MSE : 0.011253038967585676
# EPOCH (113/300)
#      EPOCH (113/300) - Observation: 1/4
#      EPOCH (113/300) - Observation: 2/4
#      EPOCH (113/300) - Observation: 3/4
#      EPOCH (113/300) - Observation: 4/4
# MSE : 0.011088319240806676
# EPOCH (114/300)
#      EPOCH (114/300) - Observation: 1/4
#      EPOCH (114/300) - Observation: 2/4
#      EPOCH (114/300) - Observation: 3/4
#      EPOCH (114/300) - Observation: 4/4
# MSE : 0.010927089790516606
# EPOCH (115/300)
#      EPOCH (115/300) - Observation: 1/4
#      EPOCH (115/300) - Observation: 2/4
#      EPOCH (115/300) - Observation: 3/4
#      EPOCH (115/300) - Observation: 4/4
# MSE : 0.010769254602784918
# EPOCH (116/300)
#      EPOCH (116/300) - Observation: 1/4
#      EPOCH (116/300) - Observation: 2/4
#      EPOCH (116/300) - Observation: 3/4
#      EPOCH (116/300) - Observation: 4/4
# MSE : 0.010614720895124555
# EPOCH (117/300)
#      EPOCH (117/300) - Observation: 1/4
#      EPOCH (117/300) - Observation: 2/4
#      EPOCH (117/300) - Observation: 3/4
#      EPOCH (117/300) - Observation: 4/4
# MSE : 0.010463398988346508
# EPOCH (118/300)
#      EPOCH (118/300) - Observation: 1/4
#      EPOCH (118/300) - Observation: 2/4
#      EPOCH (118/300) - Observation: 3/4
#      EPOCH (118/300) - Observation: 4/4
# MSE : 0.010315202184246773
# EPOCH (119/300)
#      EPOCH (119/300) - Observation: 1/4
#      EPOCH (119/300) - Observation: 2/4
#      EPOCH (119/300) - Observation: 3/4
#      EPOCH (119/300) - Observation: 4/4
# MSE : 0.01017004664882692
# EPOCH (120/300)
#      EPOCH (120/300) - Observation: 1/4
#      EPOCH (120/300) - Observation: 2/4
#      EPOCH (120/300) - Observation: 3/4
#      EPOCH (120/300) - Observation: 4/4
# MSE : 0.01002785130076642
# EPOCH (121/300)
#      EPOCH (121/300) - Observation: 1/4
#      EPOCH (121/300) - Observation: 2/4
#      EPOCH (121/300) - Observation: 3/4
#      EPOCH (121/300) - Observation: 4/4
# MSE : 0.009888537704880851
# EPOCH (122/300)
#      EPOCH (122/300) - Observation: 1/4
#      EPOCH (122/300) - Observation: 2/4
#      EPOCH (122/300) - Observation: 3/4
#      EPOCH (122/300) - Observation: 4/4
# MSE : 0.009752029970315287
# EPOCH (123/300)
#      EPOCH (123/300) - Observation: 1/4
#      EPOCH (123/300) - Observation: 2/4
#      EPOCH (123/300) - Observation: 3/4
#      EPOCH (123/300) - Observation: 4/4
# MSE : 0.009618254653235538
# EPOCH (124/300)
#      EPOCH (124/300) - Observation: 1/4
#      EPOCH (124/300) - Observation: 2/4
#      EPOCH (124/300) - Observation: 3/4
#      EPOCH (124/300) - Observation: 4/4
# MSE : 0.009487140663793796
# EPOCH (125/300)
#      EPOCH (125/300) - Observation: 1/4
#      EPOCH (125/300) - Observation: 2/4
#      EPOCH (125/300) - Observation: 3/4
#      EPOCH (125/300) - Observation: 4/4
# MSE : 0.009358619177156918
# EPOCH (126/300)
#      EPOCH (126/300) - Observation: 1/4
#      EPOCH (126/300) - Observation: 2/4
#      EPOCH (126/300) - Observation: 3/4
#      EPOCH (126/300) - Observation: 4/4
# MSE : 0.009232623548397849
# EPOCH (127/300)
#      EPOCH (127/300) - Observation: 1/4
#      EPOCH (127/300) - Observation: 2/4
#      EPOCH (127/300) - Observation: 3/4
#      EPOCH (127/300) - Observation: 4/4
# MSE : 0.009109089231060886
# EPOCH (128/300)
#      EPOCH (128/300) - Observation: 1/4
#      EPOCH (128/300) - Observation: 2/4
#      EPOCH (128/300) - Observation: 3/4
#      EPOCH (128/300) - Observation: 4/4
# MSE : 0.008987953699222326
# EPOCH (129/300)
#      EPOCH (129/300) - Observation: 1/4
#      EPOCH (129/300) - Observation: 2/4
#      EPOCH (129/300) - Observation: 3/4
#      EPOCH (129/300) - Observation: 4/4
# MSE : 0.008869156372877385
# EPOCH (130/300)
#      EPOCH (130/300) - Observation: 1/4
#      EPOCH (130/300) - Observation: 2/4
#      EPOCH (130/300) - Observation: 3/4
#      EPOCH (130/300) - Observation: 4/4
# MSE : 0.00875263854649333
# EPOCH (131/300)
#      EPOCH (131/300) - Observation: 1/4
#      EPOCH (131/300) - Observation: 2/4
#      EPOCH (131/300) - Observation: 3/4
#      EPOCH (131/300) - Observation: 4/4
# MSE : 0.008638343320577602
# EPOCH (132/300)
#      EPOCH (132/300) - Observation: 1/4
#      EPOCH (132/300) - Observation: 2/4
#      EPOCH (132/300) - Observation: 3/4
#      EPOCH (132/300) - Observation: 4/4
# MSE : 0.008526215536117225
# EPOCH (133/300)
#      EPOCH (133/300) - Observation: 1/4
#      EPOCH (133/300) - Observation: 2/4
#      EPOCH (133/300) - Observation: 3/4
#      EPOCH (133/300) - Observation: 4/4
# MSE : 0.00841620171175404
# EPOCH (134/300)
#      EPOCH (134/300) - Observation: 1/4
#      EPOCH (134/300) - Observation: 2/4
#      EPOCH (134/300) - Observation: 3/4
#      EPOCH (134/300) - Observation: 4/4
# MSE : 0.008308249983566635
# EPOCH (135/300)
#      EPOCH (135/300) - Observation: 1/4
#      EPOCH (135/300) - Observation: 2/4
#      EPOCH (135/300) - Observation: 3/4
#      EPOCH (135/300) - Observation: 4/4
# MSE : 0.008202310047337555
# EPOCH (136/300)
#      EPOCH (136/300) - Observation: 1/4
#      EPOCH (136/300) - Observation: 2/4
#      EPOCH (136/300) - Observation: 3/4
#      EPOCH (136/300) - Observation: 4/4
# MSE : 0.0080983331031895
# EPOCH (137/300)
#      EPOCH (137/300) - Observation: 1/4
#      EPOCH (137/300) - Observation: 2/4
#      EPOCH (137/300) - Observation: 3/4
#      EPOCH (137/300) - Observation: 4/4
# MSE : 0.007996271802481589
# EPOCH (138/300)
#      EPOCH (138/300) - Observation: 1/4
#      EPOCH (138/300) - Observation: 2/4
#      EPOCH (138/300) - Observation: 3/4
#      EPOCH (138/300) - Observation: 4/4
# MSE : 0.007896080196860958
# EPOCH (139/300)
#      EPOCH (139/300) - Observation: 1/4
#      EPOCH (139/300) - Observation: 2/4
#      EPOCH (139/300) - Observation: 3/4
#      EPOCH (139/300) - Observation: 4/4
# MSE : 0.007797713689371601
# EPOCH (140/300)
#      EPOCH (140/300) - Observation: 1/4
#      EPOCH (140/300) - Observation: 2/4
#      EPOCH (140/300) - Observation: 3/4
#      EPOCH (140/300) - Observation: 4/4
# MSE : 0.007701128987526252
# EPOCH (141/300)
#      EPOCH (141/300) - Observation: 1/4
#      EPOCH (141/300) - Observation: 2/4
#      EPOCH (141/300) - Observation: 3/4
#      EPOCH (141/300) - Observation: 4/4
# MSE : 0.00760628405825286
# EPOCH (142/300)
#      EPOCH (142/300) - Observation: 1/4
#      EPOCH (142/300) - Observation: 2/4
#      EPOCH (142/300) - Observation: 3/4
#      EPOCH (142/300) - Observation: 4/4
# MSE : 0.007513138084630833
# EPOCH (143/300)
#      EPOCH (143/300) - Observation: 1/4
#      EPOCH (143/300) - Observation: 2/4
#      EPOCH (143/300) - Observation: 3/4
#      EPOCH (143/300) - Observation: 4/4
# MSE : 0.0074216514243369645
# EPOCH (144/300)
#      EPOCH (144/300) - Observation: 1/4
#      EPOCH (144/300) - Observation: 2/4
#      EPOCH (144/300) - Observation: 3/4
#      EPOCH (144/300) - Observation: 4/4
# MSE : 0.007331785569724815
# EPOCH (145/300)
#      EPOCH (145/300) - Observation: 1/4
#      EPOCH (145/300) - Observation: 2/4
#      EPOCH (145/300) - Observation: 3/4
#      EPOCH (145/300) - Observation: 4/4
# MSE : 0.0072435031094650465
# EPOCH (146/300)
#      EPOCH (146/300) - Observation: 1/4
#      EPOCH (146/300) - Observation: 2/4
#      EPOCH (146/300) - Observation: 3/4
#      EPOCH (146/300) - Observation: 4/4
# MSE : 0.007156767691677937
# EPOCH (147/300)
#      EPOCH (147/300) - Observation: 1/4
#      EPOCH (147/300) - Observation: 2/4
#      EPOCH (147/300) - Observation: 3/4
#      EPOCH (147/300) - Observation: 4/4
# MSE : 0.007071543988492361
# EPOCH (148/300)
#      EPOCH (148/300) - Observation: 1/4
#      EPOCH (148/300) - Observation: 2/4
#      EPOCH (148/300) - Observation: 3/4
#      EPOCH (148/300) - Observation: 4/4
# MSE : 0.006987797661969168
# EPOCH (149/300)
#      EPOCH (149/300) - Observation: 1/4
#      EPOCH (149/300) - Observation: 2/4
#      EPOCH (149/300) - Observation: 3/4
#      EPOCH (149/300) - Observation: 4/4
# MSE : 0.006905495331329518
# EPOCH (150/300)
#      EPOCH (150/300) - Observation: 1/4
#      EPOCH (150/300) - Observation: 2/4
#      EPOCH (150/300) - Observation: 3/4
#      EPOCH (150/300) - Observation: 4/4
# MSE : 0.00682460454143184
# EPOCH (151/300)
#      EPOCH (151/300) - Observation: 1/4
#      EPOCH (151/300) - Observation: 2/4
#      EPOCH (151/300) - Observation: 3/4
#      EPOCH (151/300) - Observation: 4/4
# MSE : 0.006745093732443649
# EPOCH (152/300)
#      EPOCH (152/300) - Observation: 1/4
#      EPOCH (152/300) - Observation: 2/4
#      EPOCH (152/300) - Observation: 3/4
#      EPOCH (152/300) - Observation: 4/4
# MSE : 0.006666932210657209
# EPOCH (153/300)
#      EPOCH (153/300) - Observation: 1/4
#      EPOCH (153/300) - Observation: 2/4
#      EPOCH (153/300) - Observation: 3/4
#      EPOCH (153/300) - Observation: 4/4
# MSE : 0.006590090120400052
# EPOCH (154/300)
#      EPOCH (154/300) - Observation: 1/4
#      EPOCH (154/300) - Observation: 2/4
#      EPOCH (154/300) - Observation: 3/4
#      EPOCH (154/300) - Observation: 4/4
# MSE : 0.006514538416994446
# EPOCH (155/300)
#      EPOCH (155/300) - Observation: 1/4
#      EPOCH (155/300) - Observation: 2/4
#      EPOCH (155/300) - Observation: 3/4
#      EPOCH (155/300) - Observation: 4/4
# MSE : 0.006440248840721086
# EPOCH (156/300)
#      EPOCH (156/300) - Observation: 1/4
#      EPOCH (156/300) - Observation: 2/4
#      EPOCH (156/300) - Observation: 3/4
#      EPOCH (156/300) - Observation: 4/4
# MSE : 0.00636719389174519
# EPOCH (157/300)
#      EPOCH (157/300) - Observation: 1/4
#      EPOCH (157/300) - Observation: 2/4
#      EPOCH (157/300) - Observation: 3/4
#      EPOCH (157/300) - Observation: 4/4
# MSE : 0.006295346805964788
# EPOCH (158/300)
#      EPOCH (158/300) - Observation: 1/4
#      EPOCH (158/300) - Observation: 2/4
#      EPOCH (158/300) - Observation: 3/4
#      EPOCH (158/300) - Observation: 4/4
# MSE : 0.006224681531742817
# EPOCH (159/300)
#      EPOCH (159/300) - Observation: 1/4
#      EPOCH (159/300) - Observation: 2/4
#      EPOCH (159/300) - Observation: 3/4
#      EPOCH (159/300) - Observation: 4/4
# MSE : 0.006155172707486521
# EPOCH (160/300)
#      EPOCH (160/300) - Observation: 1/4
#      EPOCH (160/300) - Observation: 2/4
#      EPOCH (160/300) - Observation: 3/4
#      EPOCH (160/300) - Observation: 4/4
# MSE : 0.006086795640039371
# EPOCH (161/300)
#      EPOCH (161/300) - Observation: 1/4
#      EPOCH (161/300) - Observation: 2/4
#      EPOCH (161/300) - Observation: 3/4
#      EPOCH (161/300) - Observation: 4/4
# MSE : 0.006019526283852178
# EPOCH (162/300)
#      EPOCH (162/300) - Observation: 1/4
#      EPOCH (162/300) - Observation: 2/4
#      EPOCH (162/300) - Observation: 3/4
#      EPOCH (162/300) - Observation: 4/4
# MSE : 0.005953341220901661
# EPOCH (163/300)
#      EPOCH (163/300) - Observation: 1/4
#      EPOCH (163/300) - Observation: 2/4
#      EPOCH (163/300) - Observation: 3/4
#      EPOCH (163/300) - Observation: 4/4
# MSE : 0.005888217641326194
# EPOCH (164/300)
#      EPOCH (164/300) - Observation: 1/4
#      EPOCH (164/300) - Observation: 2/4
#      EPOCH (164/300) - Observation: 3/4
#      EPOCH (164/300) - Observation: 4/4
# MSE : 0.005824133324749809
# EPOCH (165/300)
#      EPOCH (165/300) - Observation: 1/4
#      EPOCH (165/300) - Observation: 2/4
#      EPOCH (165/300) - Observation: 3/4
#      EPOCH (165/300) - Observation: 4/4
# MSE : 0.005761066622266749
# EPOCH (166/300)
#      EPOCH (166/300) - Observation: 1/4
#      EPOCH (166/300) - Observation: 2/4
#      EPOCH (166/300) - Observation: 3/4
#      EPOCH (166/300) - Observation: 4/4
# MSE : 0.005698996439060304
# EPOCH (167/300)
#      EPOCH (167/300) - Observation: 1/4
#      EPOCH (167/300) - Observation: 2/4
#      EPOCH (167/300) - Observation: 3/4
#      EPOCH (167/300) - Observation: 4/4
# MSE : 0.005637902217630486
# EPOCH (168/300)
#      EPOCH (168/300) - Observation: 1/4
#      EPOCH (168/300) - Observation: 2/4
#      EPOCH (168/300) - Observation: 3/4
#      EPOCH (168/300) - Observation: 4/4
# MSE : 0.005577763921606697
# EPOCH (169/300)
#      EPOCH (169/300) - Observation: 1/4
#      EPOCH (169/300) - Observation: 2/4
#      EPOCH (169/300) - Observation: 3/4
#      EPOCH (169/300) - Observation: 4/4
# MSE : 0.005518562020122193
# EPOCH (170/300)
#      EPOCH (170/300) - Observation: 1/4
#      EPOCH (170/300) - Observation: 2/4
#      EPOCH (170/300) - Observation: 3/4
#      EPOCH (170/300) - Observation: 4/4
# MSE : 0.005460277472728224
# EPOCH (171/300)
#      EPOCH (171/300) - Observation: 1/4
#      EPOCH (171/300) - Observation: 2/4
#      EPOCH (171/300) - Observation: 3/4
#      EPOCH (171/300) - Observation: 4/4
# MSE : 0.005402891714827029
# EPOCH (172/300)
#      EPOCH (172/300) - Observation: 1/4
#      EPOCH (172/300) - Observation: 2/4
#      EPOCH (172/300) - Observation: 3/4
#      EPOCH (172/300) - Observation: 4/4
# MSE : 0.005346386643603264
# EPOCH (173/300)
#      EPOCH (173/300) - Observation: 1/4
#      EPOCH (173/300) - Observation: 2/4
#      EPOCH (173/300) - Observation: 3/4
#      EPOCH (173/300) - Observation: 4/4
# MSE : 0.005290744604434804
# EPOCH (174/300)
#      EPOCH (174/300) - Observation: 1/4
#      EPOCH (174/300) - Observation: 2/4
#      EPOCH (174/300) - Observation: 3/4
#      EPOCH (174/300) - Observation: 4/4
# MSE : 0.00523594837776427
# EPOCH (175/300)
#      EPOCH (175/300) - Observation: 1/4
#      EPOCH (175/300) - Observation: 2/4
#      EPOCH (175/300) - Observation: 3/4
#      EPOCH (175/300) - Observation: 4/4
# MSE : 0.005181981166413748
# EPOCH (176/300)
#      EPOCH (176/300) - Observation: 1/4
#      EPOCH (176/300) - Observation: 2/4
#      EPOCH (176/300) - Observation: 3/4
#      EPOCH (176/300) - Observation: 4/4
# MSE : 0.005128826583325787
# EPOCH (177/300)
#      EPOCH (177/300) - Observation: 1/4
#      EPOCH (177/300) - Observation: 2/4
#      EPOCH (177/300) - Observation: 3/4
#      EPOCH (177/300) - Observation: 4/4
# MSE : 0.005076468639714357
# EPOCH (178/300)
#      EPOCH (178/300) - Observation: 1/4
#      EPOCH (178/300) - Observation: 2/4
#      EPOCH (178/300) - Observation: 3/4
#      EPOCH (178/300) - Observation: 4/4
# MSE : 0.005024891733610431
# EPOCH (179/300)
#      EPOCH (179/300) - Observation: 1/4
#      EPOCH (179/300) - Observation: 2/4
#      EPOCH (179/300) - Observation: 3/4
#      EPOCH (179/300) - Observation: 4/4
# MSE : 0.004974080638787301
# EPOCH (180/300)
#      EPOCH (180/300) - Observation: 1/4
#      EPOCH (180/300) - Observation: 2/4
#      EPOCH (180/300) - Observation: 3/4
#      EPOCH (180/300) - Observation: 4/4
# MSE : 0.004924020494051191
# EPOCH (181/300)
#      EPOCH (181/300) - Observation: 1/4
#      EPOCH (181/300) - Observation: 2/4
#      EPOCH (181/300) - Observation: 3/4
#      EPOCH (181/300) - Observation: 4/4
# MSE : 0.004874696792883924
# EPOCH (182/300)
#      EPOCH (182/300) - Observation: 1/4
#      EPOCH (182/300) - Observation: 2/4
#      EPOCH (182/300) - Observation: 3/4
#      EPOCH (182/300) - Observation: 4/4
# MSE : 0.004826095373424171
# EPOCH (183/300)
#      EPOCH (183/300) - Observation: 1/4
#      EPOCH (183/300) - Observation: 2/4
#      EPOCH (183/300) - Observation: 3/4
#      EPOCH (183/300) - Observation: 4/4
# MSE : 0.004778202408775036
# EPOCH (184/300)
#      EPOCH (184/300) - Observation: 1/4
#      EPOCH (184/300) - Observation: 2/4
#      EPOCH (184/300) - Observation: 3/4
#      EPOCH (184/300) - Observation: 4/4
# MSE : 0.004731004397625848
# EPOCH (185/300)
#      EPOCH (185/300) - Observation: 1/4
#      EPOCH (185/300) - Observation: 2/4
#      EPOCH (185/300) - Observation: 3/4
#      EPOCH (185/300) - Observation: 4/4
# MSE : 0.004684488155176608
# EPOCH (186/300)
#      EPOCH (186/300) - Observation: 1/4
#      EPOCH (186/300) - Observation: 2/4
#      EPOCH (186/300) - Observation: 3/4
#      EPOCH (186/300) - Observation: 4/4
# MSE : 0.004638640804354169
# EPOCH (187/300)
#      EPOCH (187/300) - Observation: 1/4
#      EPOCH (187/300) - Observation: 2/4
#      EPOCH (187/300) - Observation: 3/4
#      EPOCH (187/300) - Observation: 4/4
# MSE : 0.004593449767309391
# EPOCH (188/300)
#      EPOCH (188/300) - Observation: 1/4
#      EPOCH (188/300) - Observation: 2/4
#      EPOCH (188/300) - Observation: 3/4
#      EPOCH (188/300) - Observation: 4/4
# MSE : 0.004548902757185288
# EPOCH (189/300)
#      EPOCH (189/300) - Observation: 1/4
#      EPOCH (189/300) - Observation: 2/4
#      EPOCH (189/300) - Observation: 3/4
#      EPOCH (189/300) - Observation: 4/4
# MSE : 0.004504987770146158
# EPOCH (190/300)
#      EPOCH (190/300) - Observation: 1/4
#      EPOCH (190/300) - Observation: 2/4
#      EPOCH (190/300) - Observation: 3/4
#      EPOCH (190/300) - Observation: 4/4
# MSE : 0.004461693077658635
# EPOCH (191/300)
#      EPOCH (191/300) - Observation: 1/4
#      EPOCH (191/300) - Observation: 2/4
#      EPOCH (191/300) - Observation: 3/4
#      EPOCH (191/300) - Observation: 4/4
# MSE : 0.004419007219015357
# EPOCH (192/300)
#      EPOCH (192/300) - Observation: 1/4
#      EPOCH (192/300) - Observation: 2/4
#      EPOCH (192/300) - Observation: 3/4
#      EPOCH (192/300) - Observation: 4/4
# MSE : 0.004376918994092876
# EPOCH (193/300)
#      EPOCH (193/300) - Observation: 1/4
#      EPOCH (193/300) - Observation: 2/4
#      EPOCH (193/300) - Observation: 3/4
#      EPOCH (193/300) - Observation: 4/4
# MSE : 0.004335417456335335
# EPOCH (194/300)
#      EPOCH (194/300) - Observation: 1/4
#      EPOCH (194/300) - Observation: 2/4
#      EPOCH (194/300) - Observation: 3/4
#      EPOCH (194/300) - Observation: 4/4
# MSE : 0.004294491905956065
# EPOCH (195/300)
#      EPOCH (195/300) - Observation: 1/4
#      EPOCH (195/300) - Observation: 2/4
#      EPOCH (195/300) - Observation: 3/4
#      EPOCH (195/300) - Observation: 4/4
# MSE : 0.004254131883349354
# EPOCH (196/300)
#      EPOCH (196/300) - Observation: 1/4
#      EPOCH (196/300) - Observation: 2/4
#      EPOCH (196/300) - Observation: 3/4
#      EPOCH (196/300) - Observation: 4/4
# MSE : 0.004214327162705093
# EPOCH (197/300)
#      EPOCH (197/300) - Observation: 1/4
#      EPOCH (197/300) - Observation: 2/4
#      EPOCH (197/300) - Observation: 3/4
#      EPOCH (197/300) - Observation: 4/4
# MSE : 0.004175067745819283
# EPOCH (198/300)
#      EPOCH (198/300) - Observation: 1/4
#      EPOCH (198/300) - Observation: 2/4
#      EPOCH (198/300) - Observation: 3/4
#      EPOCH (198/300) - Observation: 4/4
# MSE : 0.004136343856093425
# EPOCH (199/300)
#      EPOCH (199/300) - Observation: 1/4
#      EPOCH (199/300) - Observation: 2/4
#      EPOCH (199/300) - Observation: 3/4
#      EPOCH (199/300) - Observation: 4/4
# MSE : 0.0040981459327165005
# EPOCH (200/300)
#      EPOCH (200/300) - Observation: 1/4
#      EPOCH (200/300) - Observation: 2/4
#      EPOCH (200/300) - Observation: 3/4
#      EPOCH (200/300) - Observation: 4/4
# MSE : 0.004060464625023119
# EPOCH (201/300)
#      EPOCH (201/300) - Observation: 1/4
#      EPOCH (201/300) - Observation: 2/4
#      EPOCH (201/300) - Observation: 3/4
#      EPOCH (201/300) - Observation: 4/4
# MSE : 0.004023290787021763
# EPOCH (202/300)
#      EPOCH (202/300) - Observation: 1/4
#      EPOCH (202/300) - Observation: 2/4
#      EPOCH (202/300) - Observation: 3/4
#      EPOCH (202/300) - Observation: 4/4
# MSE : 0.003986615472087508
# EPOCH (203/300)
#      EPOCH (203/300) - Observation: 1/4
#      EPOCH (203/300) - Observation: 2/4
#      EPOCH (203/300) - Observation: 3/4
#      EPOCH (203/300) - Observation: 4/4
# MSE : 0.00395042992781337
# EPOCH (204/300)
#      EPOCH (204/300) - Observation: 1/4
#      EPOCH (204/300) - Observation: 2/4
#      EPOCH (204/300) - Observation: 3/4
#      EPOCH (204/300) - Observation: 4/4
# MSE : 0.003914725591015201
# EPOCH (205/300)
#      EPOCH (205/300) - Observation: 1/4
#      EPOCH (205/300) - Observation: 2/4
#      EPOCH (205/300) - Observation: 3/4
#      EPOCH (205/300) - Observation: 4/4
# MSE : 0.0038794940828846872
# EPOCH (206/300)
#      EPOCH (206/300) - Observation: 1/4
#      EPOCH (206/300) - Observation: 2/4
#      EPOCH (206/300) - Observation: 3/4
#      EPOCH (206/300) - Observation: 4/4
# MSE : 0.0038447272042856093
# EPOCH (207/300)
#      EPOCH (207/300) - Observation: 1/4
#      EPOCH (207/300) - Observation: 2/4
#      EPOCH (207/300) - Observation: 3/4
#      EPOCH (207/300) - Observation: 4/4
# MSE : 0.0038104169311886735
# EPOCH (208/300)
#      EPOCH (208/300) - Observation: 1/4
#      EPOCH (208/300) - Observation: 2/4
#      EPOCH (208/300) - Observation: 3/4
#      EPOCH (208/300) - Observation: 4/4
# MSE : 0.0037765554102400034
# EPOCH (209/300)
#      EPOCH (209/300) - Observation: 1/4
#      EPOCH (209/300) - Observation: 2/4
#      EPOCH (209/300) - Observation: 3/4
#      EPOCH (209/300) - Observation: 4/4
# MSE : 0.0037431349544591965
# EPOCH (210/300)
#      EPOCH (210/300) - Observation: 1/4
#      EPOCH (210/300) - Observation: 2/4
#      EPOCH (210/300) - Observation: 3/4
#      EPOCH (210/300) - Observation: 4/4
# MSE : 0.003710148039062405
# EPOCH (211/300)
#      EPOCH (211/300) - Observation: 1/4
#      EPOCH (211/300) - Observation: 2/4
#      EPOCH (211/300) - Observation: 3/4
#      EPOCH (211/300) - Observation: 4/4
# MSE : 0.003677587297406515
# EPOCH (212/300)
#      EPOCH (212/300) - Observation: 1/4
#      EPOCH (212/300) - Observation: 2/4
#      EPOCH (212/300) - Observation: 3/4
#      EPOCH (212/300) - Observation: 4/4
# MSE : 0.0036454455170502353
# EPOCH (213/300)
#      EPOCH (213/300) - Observation: 1/4
#      EPOCH (213/300) - Observation: 2/4
#      EPOCH (213/300) - Observation: 3/4
#      EPOCH (213/300) - Observation: 4/4
# MSE : 0.003613715635928557
# EPOCH (214/300)
#      EPOCH (214/300) - Observation: 1/4
#      EPOCH (214/300) - Observation: 2/4
#      EPOCH (214/300) - Observation: 3/4
#      EPOCH (214/300) - Observation: 4/4
# MSE : 0.0035823907386366336
# EPOCH (215/300)
#      EPOCH (215/300) - Observation: 1/4
#      EPOCH (215/300) - Observation: 2/4
#      EPOCH (215/300) - Observation: 3/4
#      EPOCH (215/300) - Observation: 4/4
# MSE : 0.0035514640528197007
# EPOCH (216/300)
#      EPOCH (216/300) - Observation: 1/4
#      EPOCH (216/300) - Observation: 2/4
#      EPOCH (216/300) - Observation: 3/4
#      EPOCH (216/300) - Observation: 4/4
# MSE : 0.0035209289456655346
# EPOCH (217/300)
#      EPOCH (217/300) - Observation: 1/4
#      EPOCH (217/300) - Observation: 2/4
#      EPOCH (217/300) - Observation: 3/4
#      EPOCH (217/300) - Observation: 4/4
# MSE : 0.003490778920496205
# EPOCH (218/300)
#      EPOCH (218/300) - Observation: 1/4
#      EPOCH (218/300) - Observation: 2/4
#      EPOCH (218/300) - Observation: 3/4
#      EPOCH (218/300) - Observation: 4/4
# MSE : 0.003461007613455842
# EPOCH (219/300)
#      EPOCH (219/300) - Observation: 1/4
#      EPOCH (219/300) - Observation: 2/4
#      EPOCH (219/300) - Observation: 3/4
#      EPOCH (219/300) - Observation: 4/4
# MSE : 0.0034316087902915697
# EPOCH (220/300)
#      EPOCH (220/300) - Observation: 1/4
#      EPOCH (220/300) - Observation: 2/4
#      EPOCH (220/300) - Observation: 3/4
#      EPOCH (220/300) - Observation: 4/4
# MSE : 0.0034025763432243084
# EPOCH (221/300)
#      EPOCH (221/300) - Observation: 1/4
#      EPOCH (221/300) - Observation: 2/4
#      EPOCH (221/300) - Observation: 3/4
#      EPOCH (221/300) - Observation: 4/4
# MSE : 0.0033739042879069076
# EPOCH (222/300)
#      EPOCH (222/300) - Observation: 1/4
#      EPOCH (222/300) - Observation: 2/4
#      EPOCH (222/300) - Observation: 3/4
#      EPOCH (222/300) - Observation: 4/4
# MSE : 0.0033455867604667506
# EPOCH (223/300)
#      EPOCH (223/300) - Observation: 1/4
#      EPOCH (223/300) - Observation: 2/4
#      EPOCH (223/300) - Observation: 3/4
#      EPOCH (223/300) - Observation: 4/4
# MSE : 0.0033176180146300975
# EPOCH (224/300)
#      EPOCH (224/300) - Observation: 1/4
#      EPOCH (224/300) - Observation: 2/4
#      EPOCH (224/300) - Observation: 3/4
#      EPOCH (224/300) - Observation: 4/4
# MSE : 0.0032899924189256744
# EPOCH (225/300)
#      EPOCH (225/300) - Observation: 1/4
#      EPOCH (225/300) - Observation: 2/4
#      EPOCH (225/300) - Observation: 3/4
#      EPOCH (225/300) - Observation: 4/4
# MSE : 0.0032627044539650703
# EPOCH (226/300)
#      EPOCH (226/300) - Observation: 1/4
#      EPOCH (226/300) - Observation: 2/4
#      EPOCH (226/300) - Observation: 3/4
#      EPOCH (226/300) - Observation: 4/4
# MSE : 0.0032357487097975104
# EPOCH (227/300)
#      EPOCH (227/300) - Observation: 1/4
#      EPOCH (227/300) - Observation: 2/4
#      EPOCH (227/300) - Observation: 3/4
#      EPOCH (227/300) - Observation: 4/4
# MSE : 0.0032091198833366754
# EPOCH (228/300)
#      EPOCH (228/300) - Observation: 1/4
#      EPOCH (228/300) - Observation: 2/4
#      EPOCH (228/300) - Observation: 3/4
#      EPOCH (228/300) - Observation: 4/4
# MSE : 0.003182812775857395
# EPOCH (229/300)
#      EPOCH (229/300) - Observation: 1/4
#      EPOCH (229/300) - Observation: 2/4
#      EPOCH (229/300) - Observation: 3/4
#      EPOCH (229/300) - Observation: 4/4
# MSE : 0.003156822290560065
# EPOCH (230/300)
#      EPOCH (230/300) - Observation: 1/4
#      EPOCH (230/300) - Observation: 2/4
#      EPOCH (230/300) - Observation: 3/4
#      EPOCH (230/300) - Observation: 4/4
# MSE : 0.003131143430200687
# EPOCH (231/300)
#      EPOCH (231/300) - Observation: 1/4
#      EPOCH (231/300) - Observation: 2/4
#      EPOCH (231/300) - Observation: 3/4
#      EPOCH (231/300) - Observation: 4/4
# MSE : 0.0031057712947845143
# EPOCH (232/300)
#      EPOCH (232/300) - Observation: 1/4
#      EPOCH (232/300) - Observation: 2/4
#      EPOCH (232/300) - Observation: 3/4
#      EPOCH (232/300) - Observation: 4/4
# MSE : 0.0030807010793214365
# EPOCH (233/300)
#      EPOCH (233/300) - Observation: 1/4
#      EPOCH (233/300) - Observation: 2/4
#      EPOCH (233/300) - Observation: 3/4
#      EPOCH (233/300) - Observation: 4/4
# MSE : 0.003055928071641181
# EPOCH (234/300)
#      EPOCH (234/300) - Observation: 1/4
#      EPOCH (234/300) - Observation: 2/4
#      EPOCH (234/300) - Observation: 3/4
#      EPOCH (234/300) - Observation: 4/4
# MSE : 0.003031447650266502
# EPOCH (235/300)
#      EPOCH (235/300) - Observation: 1/4
#      EPOCH (235/300) - Observation: 2/4
#      EPOCH (235/300) - Observation: 3/4
#      EPOCH (235/300) - Observation: 4/4
# MSE : 0.003007255282342698
# EPOCH (236/300)
#      EPOCH (236/300) - Observation: 1/4
#      EPOCH (236/300) - Observation: 2/4
#      EPOCH (236/300) - Observation: 3/4
#      EPOCH (236/300) - Observation: 4/4
# MSE : 0.0029833465216216725
# EPOCH (237/300)
#      EPOCH (237/300) - Observation: 1/4
#      EPOCH (237/300) - Observation: 2/4
#      EPOCH (237/300) - Observation: 3/4
#      EPOCH (237/300) - Observation: 4/4
# MSE : 0.0029597170064989964
# EPOCH (238/300)
#      EPOCH (238/300) - Observation: 1/4
#      EPOCH (238/300) - Observation: 2/4
#      EPOCH (238/300) - Observation: 3/4
#      EPOCH (238/300) - Observation: 4/4
# MSE : 0.0029363624581023383
# EPOCH (239/300)
#      EPOCH (239/300) - Observation: 1/4
#      EPOCH (239/300) - Observation: 2/4
#      EPOCH (239/300) - Observation: 3/4
#      EPOCH (239/300) - Observation: 4/4
# MSE : 0.002913278678429723
# EPOCH (240/300)
#      EPOCH (240/300) - Observation: 1/4
#      EPOCH (240/300) - Observation: 2/4
#      EPOCH (240/300) - Observation: 3/4
#      EPOCH (240/300) - Observation: 4/4
# MSE : 0.0028904615485362654
# EPOCH (241/300)
#      EPOCH (241/300) - Observation: 1/4
#      EPOCH (241/300) - Observation: 2/4
#      EPOCH (241/300) - Observation: 3/4
#      EPOCH (241/300) - Observation: 4/4
# MSE : 0.0028679070267677263
# EPOCH (242/300)
#      EPOCH (242/300) - Observation: 1/4
#      EPOCH (242/300) - Observation: 2/4
#      EPOCH (242/300) - Observation: 3/4
#      EPOCH (242/300) - Observation: 4/4
# MSE : 0.0028456111470398357
# EPOCH (243/300)
#      EPOCH (243/300) - Observation: 1/4
#      EPOCH (243/300) - Observation: 2/4
#      EPOCH (243/300) - Observation: 3/4
#      EPOCH (243/300) - Observation: 4/4
# MSE : 0.0028235700171617088
# EPOCH (244/300)
#      EPOCH (244/300) - Observation: 1/4
#      EPOCH (244/300) - Observation: 2/4
#      EPOCH (244/300) - Observation: 3/4
#      EPOCH (244/300) - Observation: 4/4
# MSE : 0.002801779817202293
# EPOCH (245/300)
#      EPOCH (245/300) - Observation: 1/4
#      EPOCH (245/300) - Observation: 2/4
#      EPOCH (245/300) - Observation: 3/4
#      EPOCH (245/300) - Observation: 4/4
# MSE : 0.0027802367978985564
# EPOCH (246/300)
#      EPOCH (246/300) - Observation: 1/4
#      EPOCH (246/300) - Observation: 2/4
#      EPOCH (246/300) - Observation: 3/4
#      EPOCH (246/300) - Observation: 4/4
# MSE : 0.00275893727910416
# EPOCH (247/300)
#      EPOCH (247/300) - Observation: 1/4
#      EPOCH (247/300) - Observation: 2/4
#      EPOCH (247/300) - Observation: 3/4
#      EPOCH (247/300) - Observation: 4/4
# MSE : 0.0027378776482774227
# EPOCH (248/300)
#      EPOCH (248/300) - Observation: 1/4
#      EPOCH (248/300) - Observation: 2/4
#      EPOCH (248/300) - Observation: 3/4
#      EPOCH (248/300) - Observation: 4/4
# MSE : 0.0027170543590076053
# EPOCH (249/300)
#      EPOCH (249/300) - Observation: 1/4
#      EPOCH (249/300) - Observation: 2/4
#      EPOCH (249/300) - Observation: 3/4
#      EPOCH (249/300) - Observation: 4/4
# MSE : 0.0026964639295782287
# EPOCH (250/300)
#      EPOCH (250/300) - Observation: 1/4
#      EPOCH (250/300) - Observation: 2/4
#      EPOCH (250/300) - Observation: 3/4
#      EPOCH (250/300) - Observation: 4/4
# MSE : 0.002676102941566471
# EPOCH (251/300)
#      EPOCH (251/300) - Observation: 1/4
#      EPOCH (251/300) - Observation: 2/4
#      EPOCH (251/300) - Observation: 3/4
#      EPOCH (251/300) - Observation: 4/4
# MSE : 0.0026559680384775864
# EPOCH (252/300)
#      EPOCH (252/300) - Observation: 1/4
#      EPOCH (252/300) - Observation: 2/4
#      EPOCH (252/300) - Observation: 3/4
#      EPOCH (252/300) - Observation: 4/4
# MSE : 0.0026360559244134477
# EPOCH (253/300)
#      EPOCH (253/300) - Observation: 1/4
#      EPOCH (253/300) - Observation: 2/4
#      EPOCH (253/300) - Observation: 3/4
#      EPOCH (253/300) - Observation: 4/4
# MSE : 0.002616363362774011
# EPOCH (254/300)
#      EPOCH (254/300) - Observation: 1/4
#      EPOCH (254/300) - Observation: 2/4
#      EPOCH (254/300) - Observation: 3/4
#      EPOCH (254/300) - Observation: 4/4
# MSE : 0.0025968871749911
# EPOCH (255/300)
#      EPOCH (255/300) - Observation: 1/4
#      EPOCH (255/300) - Observation: 2/4
#      EPOCH (255/300) - Observation: 3/4
#      EPOCH (255/300) - Observation: 4/4
# MSE : 0.002577624239293302
# EPOCH (256/300)
#      EPOCH (256/300) - Observation: 1/4
#      EPOCH (256/300) - Observation: 2/4
#      EPOCH (256/300) - Observation: 3/4
#      EPOCH (256/300) - Observation: 4/4
# MSE : 0.00255857148950131
# EPOCH (257/300)
#      EPOCH (257/300) - Observation: 1/4
#      EPOCH (257/300) - Observation: 2/4
#      EPOCH (257/300) - Observation: 3/4
#      EPOCH (257/300) - Observation: 4/4
# MSE : 0.002539725913852771
# EPOCH (258/300)
#      EPOCH (258/300) - Observation: 1/4
#      EPOCH (258/300) - Observation: 2/4
#      EPOCH (258/300) - Observation: 3/4
#      EPOCH (258/300) - Observation: 4/4
# MSE : 0.0025210845538558685
# EPOCH (259/300)
#      EPOCH (259/300) - Observation: 1/4
#      EPOCH (259/300) - Observation: 2/4
#      EPOCH (259/300) - Observation: 3/4
#      EPOCH (259/300) - Observation: 4/4
# MSE : 0.002502644503170708
# EPOCH (260/300)
#      EPOCH (260/300) - Observation: 1/4
#      EPOCH (260/300) - Observation: 2/4
#      EPOCH (260/300) - Observation: 3/4
#      EPOCH (260/300) - Observation: 4/4
# MSE : 0.002484402906518032
# EPOCH (261/300)
#      EPOCH (261/300) - Observation: 1/4
#      EPOCH (261/300) - Observation: 2/4
#      EPOCH (261/300) - Observation: 3/4
#      EPOCH (261/300) - Observation: 4/4
# MSE : 0.0024663569586141428
# EPOCH (262/300)
#      EPOCH (262/300) - Observation: 1/4
#      EPOCH (262/300) - Observation: 2/4
#      EPOCH (262/300) - Observation: 3/4
#      EPOCH (262/300) - Observation: 4/4
# MSE : 0.002448503903131616
# EPOCH (263/300)
#      EPOCH (263/300) - Observation: 1/4
#      EPOCH (263/300) - Observation: 2/4
#      EPOCH (263/300) - Observation: 3/4
#      EPOCH (263/300) - Observation: 4/4
# MSE : 0.002430841031684943
# EPOCH (264/300)
#      EPOCH (264/300) - Observation: 1/4
#      EPOCH (264/300) - Observation: 2/4
#      EPOCH (264/300) - Observation: 3/4
#      EPOCH (264/300) - Observation: 4/4
# MSE : 0.0024133656828404593
# EPOCH (265/300)
#      EPOCH (265/300) - Observation: 1/4
#      EPOCH (265/300) - Observation: 2/4
#      EPOCH (265/300) - Observation: 3/4
#      EPOCH (265/300) - Observation: 4/4
# MSE : 0.0023960752411499122
# EPOCH (266/300)
#      EPOCH (266/300) - Observation: 1/4
#      EPOCH (266/300) - Observation: 2/4
#      EPOCH (266/300) - Observation: 3/4
#      EPOCH (266/300) - Observation: 4/4
# MSE : 0.0023789671362070388
# EPOCH (267/300)
#      EPOCH (267/300) - Observation: 1/4
#      EPOCH (267/300) - Observation: 2/4
#      EPOCH (267/300) - Observation: 3/4
#      EPOCH (267/300) - Observation: 4/4
# MSE : 0.0023620388417265044
# EPOCH (268/300)
#      EPOCH (268/300) - Observation: 1/4
#      EPOCH (268/300) - Observation: 2/4
#      EPOCH (268/300) - Observation: 3/4
#      EPOCH (268/300) - Observation: 4/4
# MSE : 0.002345287874644558
# EPOCH (269/300)
#      EPOCH (269/300) - Observation: 1/4
#      EPOCH (269/300) - Observation: 2/4
#      EPOCH (269/300) - Observation: 3/4
#      EPOCH (269/300) - Observation: 4/4
# MSE : 0.0023287117942409905
# EPOCH (270/300)
#      EPOCH (270/300) - Observation: 1/4
#      EPOCH (270/300) - Observation: 2/4
#      EPOCH (270/300) - Observation: 3/4
#      EPOCH (270/300) - Observation: 4/4
# MSE : 0.002312308201281605
# EPOCH (271/300)
#      EPOCH (271/300) - Observation: 1/4
#      EPOCH (271/300) - Observation: 2/4
#      EPOCH (271/300) - Observation: 3/4
#      EPOCH (271/300) - Observation: 4/4
# MSE : 0.0022960747371808146
# EPOCH (272/300)
#      EPOCH (272/300) - Observation: 1/4
#      EPOCH (272/300) - Observation: 2/4
#      EPOCH (272/300) - Observation: 3/4
#      EPOCH (272/300) - Observation: 4/4
# MSE : 0.0022800090831837892
# EPOCH (273/300)
#      EPOCH (273/300) - Observation: 1/4
#      EPOCH (273/300) - Observation: 2/4
#      EPOCH (273/300) - Observation: 3/4
#      EPOCH (273/300) - Observation: 4/4
# MSE : 0.0022641089595675755
# EPOCH (274/300)
#      EPOCH (274/300) - Observation: 1/4
#      EPOCH (274/300) - Observation: 2/4
#      EPOCH (274/300) - Observation: 3/4
#      EPOCH (274/300) - Observation: 4/4
# MSE : 0.0022483721248608116
# EPOCH (275/300)
#      EPOCH (275/300) - Observation: 1/4
#      EPOCH (275/300) - Observation: 2/4
#      EPOCH (275/300) - Observation: 3/4
#      EPOCH (275/300) - Observation: 4/4
# MSE : 0.0022327963750813865
# EPOCH (276/300)
#      EPOCH (276/300) - Observation: 1/4
#      EPOCH (276/300) - Observation: 2/4
#      EPOCH (276/300) - Observation: 3/4
#      EPOCH (276/300) - Observation: 4/4
# MSE : 0.002217379542991755
# EPOCH (277/300)
#      EPOCH (277/300) - Observation: 1/4
#      EPOCH (277/300) - Observation: 2/4
#      EPOCH (277/300) - Observation: 3/4
#      EPOCH (277/300) - Observation: 4/4
# MSE : 0.0022021194973713028
# EPOCH (278/300)
#      EPOCH (278/300) - Observation: 1/4
#      EPOCH (278/300) - Observation: 2/4
#      EPOCH (278/300) - Observation: 3/4
#      EPOCH (278/300) - Observation: 4/4
# MSE : 0.0021870141423053647
# EPOCH (279/300)
#      EPOCH (279/300) - Observation: 1/4
#      EPOCH (279/300) - Observation: 2/4
#      EPOCH (279/300) - Observation: 3/4
#      EPOCH (279/300) - Observation: 4/4
# MSE : 0.002172061416490505
# EPOCH (280/300)
#      EPOCH (280/300) - Observation: 1/4
#      EPOCH (280/300) - Observation: 2/4
#      EPOCH (280/300) - Observation: 3/4
#      EPOCH (280/300) - Observation: 4/4
# MSE : 0.002157259292555573
# EPOCH (281/300)
#      EPOCH (281/300) - Observation: 1/4
#      EPOCH (281/300) - Observation: 2/4
#      EPOCH (281/300) - Observation: 3/4
#      EPOCH (281/300) - Observation: 4/4
# MSE : 0.0021426057763981768
# EPOCH (282/300)
#      EPOCH (282/300) - Observation: 1/4
#      EPOCH (282/300) - Observation: 2/4
#      EPOCH (282/300) - Observation: 3/4
#      EPOCH (282/300) - Observation: 4/4
# MSE : 0.0021280989065361657
# EPOCH (283/300)
#      EPOCH (283/300) - Observation: 1/4
#      EPOCH (283/300) - Observation: 2/4
#      EPOCH (283/300) - Observation: 3/4
#      EPOCH (283/300) - Observation: 4/4
# MSE : 0.0021137367534736938
# EPOCH (284/300)
#      EPOCH (284/300) - Observation: 1/4
#      EPOCH (284/300) - Observation: 2/4
#      EPOCH (284/300) - Observation: 3/4
#      EPOCH (284/300) - Observation: 4/4
# MSE : 0.0020995174190815576
# EPOCH (285/300)
#      EPOCH (285/300) - Observation: 1/4
#      EPOCH (285/300) - Observation: 2/4
#      EPOCH (285/300) - Observation: 3/4
#      EPOCH (285/300) - Observation: 4/4
# MSE : 0.002085439035991434
# EPOCH (286/300)
#      EPOCH (286/300) - Observation: 1/4
#      EPOCH (286/300) - Observation: 2/4
#      EPOCH (286/300) - Observation: 3/4
#      EPOCH (286/300) - Observation: 4/4
# MSE : 0.0020714997670035927
# EPOCH (287/300)
#      EPOCH (287/300) - Observation: 1/4
#      EPOCH (287/300) - Observation: 2/4
#      EPOCH (287/300) - Observation: 3/4
#      EPOCH (287/300) - Observation: 4/4
# MSE : 0.00205769780450785
# EPOCH (288/300)
#      EPOCH (288/300) - Observation: 1/4
#      EPOCH (288/300) - Observation: 2/4
#      EPOCH (288/300) - Observation: 3/4
#      EPOCH (288/300) - Observation: 4/4
# MSE : 0.0020440313699173307
# EPOCH (289/300)
#      EPOCH (289/300) - Observation: 1/4
#      EPOCH (289/300) - Observation: 2/4
#      EPOCH (289/300) - Observation: 3/4
#      EPOCH (289/300) - Observation: 4/4
# MSE : 0.0020304987131148314
# EPOCH (290/300)
#      EPOCH (290/300) - Observation: 1/4
#      EPOCH (290/300) - Observation: 2/4
#      EPOCH (290/300) - Observation: 3/4
#      EPOCH (290/300) - Observation: 4/4
# MSE : 0.002017098111911283
# EPOCH (291/300)
#      EPOCH (291/300) - Observation: 1/4
#      EPOCH (291/300) - Observation: 2/4
#      EPOCH (291/300) - Observation: 3/4
#      EPOCH (291/300) - Observation: 4/4
# MSE : 0.0020038278715162287
# EPOCH (292/300)
#      EPOCH (292/300) - Observation: 1/4
#      EPOCH (292/300) - Observation: 2/4
#      EPOCH (292/300) - Observation: 3/4
#      EPOCH (292/300) - Observation: 4/4
# MSE : 0.0019906863240198966
# EPOCH (293/300)
#      EPOCH (293/300) - Observation: 1/4
#      EPOCH (293/300) - Observation: 2/4
#      EPOCH (293/300) - Observation: 3/4
#      EPOCH (293/300) - Observation: 4/4
# MSE : 0.001977671827886537
# EPOCH (294/300)
#      EPOCH (294/300) - Observation: 1/4
#      EPOCH (294/300) - Observation: 2/4
#      EPOCH (294/300) - Observation: 3/4
#      EPOCH (294/300) - Observation: 4/4
# MSE : 0.0019647827674588794
# EPOCH (295/300)
#      EPOCH (295/300) - Observation: 1/4
#      EPOCH (295/300) - Observation: 2/4
#      EPOCH (295/300) - Observation: 3/4
#      EPOCH (295/300) - Observation: 4/4
# MSE : 0.0019520175524732784
# EPOCH (296/300)
#      EPOCH (296/300) - Observation: 1/4
#      EPOCH (296/300) - Observation: 2/4
#      EPOCH (296/300) - Observation: 3/4
#      EPOCH (296/300) - Observation: 4/4
# MSE : 0.0019393746175854795
# EPOCH (297/300)
#      EPOCH (297/300) - Observation: 1/4
#      EPOCH (297/300) - Observation: 2/4
#      EPOCH (297/300) - Observation: 3/4
#      EPOCH (297/300) - Observation: 4/4
# MSE : 0.0019268524219065056
# EPOCH (298/300)
#      EPOCH (298/300) - Observation: 1/4
#      EPOCH (298/300) - Observation: 2/4
#      EPOCH (298/300) - Observation: 3/4
#      EPOCH (298/300) - Observation: 4/4
# MSE : 0.0019144494485486198
# EPOCH (299/300)
#      EPOCH (299/300) - Observation: 1/4
#      EPOCH (299/300) - Observation: 2/4
#      EPOCH (299/300) - Observation: 3/4
#      EPOCH (299/300) - Observation: 4/4
# MSE : 0.0019021642041810295

# %%
#@title 6 - monitoring

#### Les données qui ont été stockées pendant l'apprentissage sur la fonction
#### de perte vont être affichées pour être analysées

import matplotlib.pyplot as plt
plt.plot(Graphique_MSE)
plt.ylabel('MSE')
plt.show()

# Recommencer l'apprentissage en modifiant largement l'hyper paramètre epoch
# et monitorer les résultats pour comparer

# %%
#@title 7 - la prédiction

#### Vérification du bon comportement du perceptron

# Affichage des poids obtenus à la fin de l'apprentissage
print ("Poids finaux: " )
print ("W11 = "+str(w11))
print ("W21 = "+str(w21))
print ("Wb = "+str(wb))

# Chargement des données d'entrée pour une observation donnée
x1 = 0
x2 = 1

# Etape 1 : Calcul de la somme pondérée


# Etape 2 : Application de la fonction d'activation


print("Prédiction du [" + str(x1) + "," + str(x2) + "]")
print("Prédiction = " + str(yp))

# Constatez le résultat obtenu et recommencez avec une nouvelle prédiction
# Out:
# Poids finaux:
# W11 = -6.329878982047043
# W21 = 0.3648460811097152
# Wb = 2.768185853342537
# Prédiction du [0,1]
# Prédiction = 0.03973694264438874
