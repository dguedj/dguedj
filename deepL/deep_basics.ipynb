# %% [markdown]
# Imports

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
#load the dataset
data_path = "kc_house_data.csv"
df_house = pd.read_csv(data_path)

# %%
#print the head
df_house.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
#printing the shape and size of dataframe
df_house.shape
# Out:
# (21613, 21)

# %%
#printing count of all colums and check for null
df_house.count()
# Out:
# id               21613
# date             21613
# price            21613
# bedrooms         21613
# bathrooms        21613
# sqft_living      21613
# sqft_lot         21613
# floors           21613
# waterfront       21613
# view             21613
# condition        21613
# grade            21613
# sqft_above       21613
# sqft_basement    21613
# yr_built         21613
# yr_renovated     21613
# zipcode          21613
# lat              21613
# long             21613
# sqft_living15    21613
# sqft_lot15       21613
# dtype: int64

# %%
#describe more insights about the dataframe
df_house.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
#columns data types
df_house.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
df_house.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %% [markdown]
# On va convertir le type de la colonne date

# %%
#create a new column reg_year
#ne prendre que les 4 premiers caractères de chaque élément de date 
#pour faire apparaître l'année
df_house['reg_year'] = df_house['date'].str[:4]

# %%
df_house.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...        1180              0
# 1      7242     2.0           0     0  ...        2170            400
# 2     10000     1.0           0     0  ...         770              0
# 3      5000     1.0           0     0  ...        1050            910
# 4      8080     1.0           0     0  ...        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
#convert the data to integer and print types
df_house['reg_year'] = df_house['reg_year'].astype('int')
df_house.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...        1180              0
# 1      7242     2.0           0     0  ...        2170            400
# 2     10000     1.0           0     0  ...         770              0
# 3      5000     1.0           0     0  ...        1050            910
# 4      8080     1.0           0     0  ...        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
df_house.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# reg_year           int32
# dtype: object

# %%
#create a new column called house_age
df_house['house_age'] = np.NaN

# %%
df_house.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  sqft_basement  yr_built  \
# 0      5650     1.0           0     0  ...              0      1955
# 1      7242     2.0           0     0  ...            400      1951
# 2     10000     1.0           0     0  ...              0      1933
# 3      5000     1.0           0     0  ...            910      1965
# 4      8080     1.0           0     0  ...              0      1987
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15  \
# ...

# %%
df_house['house_age'] = np.where(
    df_house['yr_renovated'] == 0.0,
    df_house['reg_year'] - df_house['yr_built'],
    df_house['reg_year'] - df_house['yr_renovated']
)

# %%
df_house.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  sqft_basement  yr_built  \
# 0      5650     1.0           0     0  ...              0      1955
# 1      7242     2.0           0     0  ...            400      1951
# 2     10000     1.0           0     0  ...              0      1933
# 3      5000     1.0           0     0  ...            910      1965
# 4      8080     1.0           0     0  ...              0      1987
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15  \
# ...

# %%
#remove
df_house.drop(['date', 'yr_built','yr_renovated', 'reg_year'], axis=1, inplace=True)

# %%
df_house.head()
# Out:
#            id     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520  221900.0         3       1.00         1180      5650     1.0
# 1  6414100192  538000.0         3       2.25         2570      7242     2.0
# 2  5631500400  180000.0         2       1.00          770     10000     1.0
# 3  2487200875  604000.0         4       3.00         1960      5000     1.0
# 4  1954400510  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  zipcode  \
# 0           0     0          3      7        1180              0    98178
# 1           0     0          3      7        2170            400    98125
# 2           0     0          3      6         770              0    98028
# 3           0     0          5      7        1050            910    98136
# 4           0     0          3      8        1680              0    98074
#
#        lat     long  sqft_living15  sqft_lot15  house_age
# ...

# %%
df_house.drop(['id','lat','zipcode', 'long'], axis=1, inplace=True)

# %%
df_house.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  sqft_living15  \
# 0     0          3      7        1180              0           1340
# 1     0          3      7        2170            400           1690
# 2     0          3      6         770              0           2720
# 3     0          5      7        1050            910           1360
# 4     0          3      8        1680              0           1800
#
#    sqft_lot15  house_age
# 0        5650         59
# 1        7639         23
# ...

# %%
df_house.describe()
# Out:
#               price      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  2.161300e+04
# mean   5.400881e+05      3.370842      2.114757   2079.899736  1.510697e+04
# std    3.671272e+05      0.930062      0.770163    918.440897  4.142051e+04
# min    7.500000e+04      0.000000      0.000000    290.000000  5.200000e+02
# 25%    3.219500e+05      3.000000      1.750000   1427.000000  5.040000e+03
# 50%    4.500000e+05      3.000000      2.250000   1910.000000  7.618000e+03
# 75%    6.450000e+05      4.000000      2.500000   2550.000000  1.068800e+04
# max    7.700000e+06     33.000000      8.000000  13540.000000  1.651359e+06
#
#              floors    waterfront          view     condition         grade  \
# count  21613.000000  21613.000000  21613.000000  21613.000000  21613.000000
# mean       1.494309      0.007542      0.234303      3.409430      7.656873
# ...

# %%
df_house = df_house[df_house['house_age']!=-1]

# %%
df_house.describe()
# Out:
#               price      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  2.159500e+04  21595.000000  21595.000000  21595.000000  2.159500e+04
# mean   5.401024e+05      3.370688      2.114367   2079.528734  1.511339e+04
# std    3.672462e+05      0.929776      0.770035    918.132213  4.143640e+04
# min    7.500000e+04      0.000000      0.000000    290.000000  5.200000e+02
# 25%    3.215000e+05      3.000000      1.750000   1428.500000  5.041000e+03
# 50%    4.500000e+05      3.000000      2.250000   1910.000000  7.620000e+03
# 75%    6.450000e+05      4.000000      2.500000   2550.000000  1.069550e+04
# max    7.700000e+06     33.000000      8.000000  13540.000000  1.651359e+06
#
#              floors    waterfront          view     condition         grade  \
# count  21595.000000  21595.000000  21595.000000  21595.000000  21595.000000
# mean       1.493887      0.007548      0.233897      3.409771      7.656263
# ...

# %% [markdown]
# Visualization

# %%
print(sns.__version__)
print(pd.__version__)
# Out:
# 0.13.2
# 2.1.4

# %%
for i in df_house.columns:
    sns.displot(df_house[i])
    plt.show()

# %%
#pairplot
plt.figure()
sns.pairplot(df_house)
plt.show()

# %%
#plotting a heat map
plt.figure(figsize=(20,10))
sns.heatmap(df_house.corr(), annot=True)
plt.show()

# %%
#boxplot for all columns
for i in df_house.columns:
    sns.boxplot(x=df_house[i])
    plt.show()

# %% [markdown]
# Define the keras model

# %%
#Define the keras model
#split the dataframe
X = df_house.drop('price', axis=1)
y = df_house['price']

# %%
y.shape
# Out:
# (21595,)

# %%
X.shape
# Out:
# (21595, 14)

# %%
#Define the keras model
modelk = keras.Sequential()
modelk.add(layers.Dense(14, activation = 'relu'))
modelk.add(layers.Dense(4, activation = 'relu'))
modelk.add(layers.Dense(1))

# %% [markdown]
# Parametrics

# %%
#compile and fit the model
modelk.compile(loss='mse', optimizer='adam')
history = modelk.fit(X, y, validation_split=0.33, batch_size=32, epochs=30)
# Out:
# Epoch 1/30
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 398021689344.0000 - val_loss: 332723126272.0000
# Epoch 2/30
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 287305531392.0000 - val_loss: 271637823488.0000
# Epoch 3/30
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 242936446976.0000 - val_loss: 181189738496.0000
# Epoch 4/30
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 142455914496.0000 - val_loss: 94574215168.0000
# Epoch 5/30
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 91749195776.0000 - val_loss: 72918630400.0000
# Epoch 6/30
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 69670420480.0000 - val_loss: 71232454656.0000
# Epoch 7/30
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 81819238400.0000 - val_loss: 70560677888.0000
# Epoch 8/30
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 73122488320.0000 - val_loss: 70104399872.0000
# Epoch 9/30
# 453/453 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 64794918912.0000 - val_loss: 69982355456.0000
# ...

# %% [markdown]
# Visualization

# %%
#plot graph
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc ='upper left')
plt.show()
